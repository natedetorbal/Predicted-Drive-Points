# %% [markdown]
# # Predicted Drive Points
# ### By Nate DeTorbal
#
# Background Information on the project is found in 'README.md' document in repository.

# %%
#libraries for plotting
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

#libraries for data cleaning and tidying
import pandas as pd
import numpy as np

#Libraries for model
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, roc_curve, accuracy_score

#Plot style
plt.style.use('fivethirtyeight')
#Plot sizing
plt.rcParams["figure.figsize"] = [15, 7.5]

# %%
#read in data
pbp18 = pd.read_csv('data/pbp18.csv')
drives18 = pd.read_csv('data/drives18.csv')

# %%
#get rid of Unnamed column
pbp18.drop('Unnamed: 0', axis = 1, inplace = True)
drives18.drop('Unnamed: 0', axis = 1, inplace = True)

#view first five rows
pbp18.head(5)
# Out:
#      game_id    drive_id             play_id     home        away  \
# 0  401012246  4010122461  401012246101849902  Alabama  Louisville
# 1  401012246  4010122461  401012246101857401  Alabama  Louisville
# 2  401012246  4010122461  401012246101858901  Alabama  Louisville
# 3  401012246  4010122461  401012246101864901  Alabama  Louisville
# 4  401012246  4010122461  401012246101867401  Alabama  Louisville
#
#   offense_team defense_team  down  distance  yard_line  ...  ytg  \
# 0   Louisville      Alabama     1        10         65  ...   65
# 1      Alabama   Louisville     1        10         35  ...   65
# 2      Alabama   Louisville     2         7         38  ...   62
# 3      Alabama   Louisville     3        13         32  ...   68
# 4      Alabama   Louisville     1        10         46  ...   54
#
#                                            play_text       play_type  \
# 0                     Evan O'Hara kickoff for 58 yds         Kickoff
# 1         Damien Harris run for 3 yds to the Alab 38            Rush
# 2  Tua Tagovailoa sacked by G.G. Robinson for a l...            Sack
# 3  Tua Tagovailoa pass complete to Damien Harris ...  Pass Reception
# 4  Tua Tagovailoa pass complete to Irv Smith Jr. ...  Pass Reception
#
#         ppa  scoring  qtr  offense_score  defense_score  offense_conf  \
# 0       NaN    False    1              0              0           ACC
# 1 -0.406231    False    1              0              0           SEC
# 2 -1.426442    False    1              0              0           SEC
# 3  2.890492    False    1              0              0           SEC
# 4  0.646573    False    1              0              0           SEC
#
#   defense_conf
# 0          SEC
# 1          ACC
# 2          ACC
# 3          ACC
# 4          ACC
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Add a few features to our data set

# %%
#add success column -- the used cutoffs are used by Football Outsiders
#(SportsSource Analytics uses .4, .5, conversion, conversion splits)
pbp18['success'] = np.where((pbp18['yards_gained'] >= .5 * pbp18['distance']) & (pbp18['down'] == 1), 1, 
                           np.where((pbp18['yards_gained'] >= .7 * pbp18['distance']) & (pbp18['down'] == 2), 1, 
                                   np.where((pbp18['yards_gained'] >= pbp18['distance']) & ((pbp18['down'] == 3) | (pbp18['down'] == 4)), 1, 0)))

#add ppa success column -- sucess if ppa > 0
pbp18['ppa_success'] = np.where(pbp18['ppa'] > 0, 1, 0)

#add score differential column
pbp18['score_diff'] = pbp18['offense_score'] - pbp18['defense_score']

#add absolute value score differential column
pbp18['abs_diff'] = abs(pbp18['score_diff'])

#view some of the added features and see if they worked properly
pbp18[['down', 'distance', 'yards_gained', 'ytg', 'success', 'play_text', 'ppa', 'ppa_success', 'abs_diff', 'drive_id']].head(5)
# Out:
#    down  distance  yards_gained  ytg  success  \
# 0     1        10             0   65        0
# 1     1        10             3   65        0
# 2     2         7            -6   62        0
# 3     3        13            14   68        1
# 4     1        10             7   54        1
#
#                                            play_text       ppa  ppa_success  \
# 0                     Evan O'Hara kickoff for 58 yds       NaN            0
# 1         Damien Harris run for 3 yds to the Alab 38 -0.406231            0
# 2  Tua Tagovailoa sacked by G.G. Robinson for a l... -1.426442            0
# 3  Tua Tagovailoa pass complete to Damien Harris ...  2.890492            1
# 4  Tua Tagovailoa pass complete to Irv Smith Jr. ...  0.646573            1
#
#    abs_diff    drive_id
# 0         0  4010122461
# 1         0  4010122461
# 2         0  4010122461
# 3         0  4010122461
# 4         0  4010122461

# %%
#get drives data from pbp data -- filter out certain plays (Kickoffs, Punts)
#get ppa per play, ppa success, success rate from pbp data 
drive_advanced_stats = pbp18.query('(play_type != "Kickoff") & (play_type ! = "Punt") & (play_type != "Timeout") & (play_type != "Uncategorized")').groupby('drive_id').agg(ppa_per_play = ('ppa', 'mean'), sr = ('success', 'mean'), ppa_sr = ('ppa_success', 'mean')).reset_index()

#join drives18 with drives advanced stats
drives18 = drives18.merge(drive_advanced_stats, how = 'inner', on = 'drive_id')

#add reduced_result variable to make limited result classifications
drives18['reduced_result'] = np.where(drives18['drive_result'] == 'TD', 'TD', 
        np.where(drives18['drive_result'] == 'FG', 'FG', 
                 np.where(drives18['drive_result'].isin(['FUMBLE', 'INT', 'INT TD', 'FUMBLE TD', 'FUMBLE RETURN TD']), 'TO', 
                          'NON-SCORE')))

drives18.head(5)
# Out:
#      drive_id     offense     defense  drive_number  start_period  \
# 0  4010122461     Alabama  Louisville             1             1
# 1  4010122462  Louisville     Alabama             2             1
# 2  4010122463     Alabama  Louisville             3             1
# 3  4010122464  Louisville     Alabama             4             1
# 4  4010122465     Alabama  Louisville             5             1
#
#    start_time_min  start_time_sec  start_yardline  start_ytg drive_result  \
# 0              15               0              35         65           TD
# 1              11              55              75         75         PUNT
# 2              10              10              20         80       FUMBLE
# 3               7               4              83         83         PUNT
# 4               6               4              45         55           TD
#
#    ...  end_yardline  end_ytg  num_plays  score  yards_gained    game_id  \
# 0  ...           100        0          7   True            65  401012246
# 1  ...            55       55          4  False            20  401012246
# 2  ...            65       35          8  False            63  401012246
# 3  ...            84       84          3  False            -1  401012246
# 4  ...           100        0          6   True            55  401012246
#
#    ppa_per_play        sr    ppa_sr  reduced_result
# 0      0.748960  0.714286  0.714286              TD
# 1     -0.091160  0.500000  0.500000       NON-SCORE
# 2      0.451487  0.500000  0.375000              TO
# 3     -0.200389  0.000000  0.000000       NON-SCORE
# 4      0.712769  0.833333  0.666667              TD
#
# [5 rows x 23 columns]

# %%
#import packages to run model
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#metrics for validating model
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, roc_curve, accuracy_score

# %%
#get rid of nan values -- happens on kickoff-turnovers
drives18 = drives18[-drives18.isnull().any(axis = 1)]

#get model data
drives_model_data = drives18[['start_period', 'start_ytg', 'end_period', 'ppa_per_play', 'sr', 'reduced_result', 'num_plays']]

#split model data into test and training sets
train, test = train_test_split(drives_model_data, test_size = .25, stratify = drives_model_data.reduced_result, random_state = 801)

#split into x's and y's
x_train = train.drop('reduced_result', axis = 1)
x_test = test.drop('reduced_result', axis = 1)
y_train = train['reduced_result']
y_test = test['reduced_result']

# %%
#optimize model parameters (**this takes a long time to run)
parameters = {'max_depth':list(range(1, 15, 1))}
gb_par = GradientBoostingClassifier()

# *** comment out below lines so it does not need to run every time I restart the Kernel

#param_gb = GridSearchCV(gb_par, parameters)
#param_gb.fit(x_train, y_train)

#print out optimal parameter
#print(param_gb.best_params_)

#optimal max_depth is 6

# %%
#Gradient Boosting -- use parameter found above
gb = GradientBoostingClassifier(max_depth = 6)
gb.fit(x_train, y_train)
yhat_gb = (gb.predict(x_test))

# %%
#Validating metric:
print('Gradient Boosting:')
print('Accuracy:', accuracy_score(y_test, yhat_gb))
# Out:
# Gradient Boosting:
# Accuracy: 0.8648938068891665

# %%
#add predictions to drives18
drives18['preds'] = pd.Series(gb.predict(drives_model_data.drop('reduced_result', axis = 1)))

#add quantitative varaible that represents classifications
drives18['actual_points'] = np.where(drives18['reduced_result'] == "TD", 7, 
                             np.where(drives18['reduced_result'] == "FG", 3, 0))
drives18['predicted_points'] = np.where(drives18['preds'] == "TD", 7, 
                             np.where(drives18['preds'] == "FG", 3, 0))

# %% [markdown]
# # TEST THE MODEL (with 2020 data)

# %%
#read in 2020 data
pbp20 = pd.read_csv('data/pbp20.csv')
drives20 = pd.read_csv('data/drives20.csv')

# %% [markdown]
# #### CLEAN 2020 data to use in the model -- take the same steps we did to get the 2018 data ready for the

# %%
#get rid of Unnamed column
pbp20.drop('Unnamed: 0', axis = 1, inplace = True)
drives20.drop('Unnamed: 0', axis = 1, inplace = True)

#add success column
pbp20['success'] = np.where((pbp20['yards_gained'] >= .5 * pbp20['distance']) & (pbp20['down'] == 1), 1, 
                           np.where((pbp20['yards_gained'] >= .7 * pbp20['distance']) & (pbp20['down'] == 2), 1, 
                                   np.where((pbp20['yards_gained'] >= pbp20['distance']) & ((pbp20['down'] == 3) | (pbp20['down'] == 4)), 1, 0)))

#add ppa success column
pbp20['ppa_success'] = np.where(pbp20['ppa'] > 0, 1, 0)

#add score differential column
pbp20['score_diff'] = pbp20['offense_score'] - pbp20['defense_score']

#add absolute value score differential column
pbp20['abs_diff'] = abs(pbp20['score_diff'])

#get drives data from pbp data -- filter out certain plays (Kickoffs, Punts)
drive_advanced_stats20 = pbp20.query('(play_type != "Kickoff") & (play_type ! = "Punt") & (play_type != "Timeout") & (play_type != "Uncategorized")').groupby('drive_id').agg(ppa_per_play = ('ppa', 'mean'), sr = ('success', 'mean'), ppa_sr = ('ppa_success', 'mean')).reset_index()

#join drives20 with drives advanced stats
drives20 = drives20.merge(drive_advanced_stats20, how = 'inner', on = 'drive_id')

#add reduced_result variable to make limited result classifications
drives20['reduced_result'] = np.where(drives20['drive_result'] == 'TD', 'TD', 
        np.where(drives20['drive_result'] == 'FG', 'FG', 
                np.where(drives20['drive_result'].isin(['FUMBLE', 'INT', 'INT TD', 'FUMBLE TD', 'FUMBLE RETURN TD']), 'TO', 
                        'NON-SCORE')))

#get 2020 data in a format that can be passed into the model
drives20 = drives20[-drives20.isnull().any(axis = 1)]
drives_model_data20 = drives20[['start_period', 'start_ytg', 'end_period', 'ppa_per_play', 'sr', 'num_plays']]

#get predictions for 2020 and add predictions to dataframe
drives20['preds'] = gb.predict(drives_model_data20)

#add actual points to results and predictions
drives20['actual_points'] = np.where(drives20['reduced_result'] == "TD", 7, 
                             np.where(drives20['reduced_result'] == "FG", 3, 0))
drives20['predicted_points'] = np.where(drives20['preds'] == "TD", 7, 
                             np.where(drives20['preds'] == "FG", 3, 0))

# %% [markdown]
# ## How did the model do in classifying the 2020 season?

# %%
#get classification data
td = drives20.query('reduced_result == "TD"')['preds']
fg = drives20.query('reduced_result == "FG"')['preds']
ns = drives20.query('reduced_result == "NON-SCORE"')['preds']
to = drives20.query('reduced_result == "TO"')['preds']

#plot classification data
fig, axs = plt.subplots(2, 2)
axs[0, 0].hist(x = td)
axs[0, 0].set_title('\nTouchdown Classifications')
axs[0, 1].hist(x = fg, color = 'forestgreen')
axs[0, 1].set_title('\nField Goal Classifications')
axs[1, 0].hist(x = ns ,color = 'gold')
axs[1, 0].set_title('\n\nNon-Score Classifications')
axs[1, 1].hist(x = to, color = 'red')
axs[1, 1].set_title('\n\nTurnover Classifications')
plt.tight_layout()

# %% [markdown]
# The above plot shows the number of classifications the model made per actual drive result. For example, the top left bar chart shows how the model classified drives that were actually touchdowns. From these charts, we can see that touchdown drives and non-score drives seem to be the easiest to classify. Field Goals are a little harder for the model to predict, and turnovers are the hardest result to predict. This matches some of our pre-model intuition becuase turnovers could happen a yard or two before scoring a touchdown on an overall successful drive.

# %%
#get dataframe of comparison between actual and predicted points 
points_per_drive = drives20.groupby('offense').agg(actual_avg = ('actual_points', 'mean'), actual_total = ('actual_points', 'sum'), pred_avg = ('predicted_points', 'mean'), pred_total = ('predicted_points', 'sum'), num_drives = ('drive_id', 'count')).sort_values('pred_avg', ascending = False).reset_index().query('num_drives > 35')
points_per_drive['diff_total'] = points_per_drive['actual_total'] - points_per_drive['pred_total']

points_per_drive.head(5)
# Out:
#             offense  actual_avg  actual_total  pred_avg  pred_total  \
# 0        Kent State    4.102041           201  4.183673         205
# 1           Alabama    3.946667           592  4.020000         603
# 2               BYU    3.798507           509  3.858209         517
# 3  Western Michigan    3.371429           236  3.557143         249
# 4  Coastal Carolina    3.330827           443  3.443609         458
#
#    num_drives  diff_total
# 0          49          -4
# 1         150         -11
# 2         134          -8
# 3          70         -13
# 4         133         -15

# %%
## Plot Actual vs Predicted Points per Drive

#define function to get paths to logos (in logos file in working directory)
def getImage(path):
    return OffsetImage(plt.imread("./logos/{0}.png".format(path)))

#get team names to put into file path later
paths = points_per_drive['offense']

x = points_per_drive['actual_avg']
y = points_per_drive['pred_avg']

#instantiate plot
fig, ax = plt.subplots()
ax.scatter(x, y) 

# Cycle through each point and add an image annotation
for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

# Define labels and title
plt.title("Predicted Offensive Points vs Actual Offensive Points\n(2020)\n")
plt.xlabel('\nActual Average Points per Drive\n')
plt.ylabel('Predicted Average Points per Drive\n')
plt.show()

# %% [markdown]
# The above plot shows the overall Actual Average Points per Drive scored by a team compared with the Predicted Average Points per Drive scored. On an average basis, it seems as if these two numbers are pretty similar over the course of the 2020 season. This was expected because again, this is on an on average basis. I believe the predictions of the model will be more interesting on a single-game basis.

# %%
#look at over and under acheivers
points_per_drive.sort_values('diff_total', ascending = False)

## ** could use prediction intervals here and see who is outside the prediction intervals
# Out:
#               offense  actual_avg  actual_total  pred_avg  pred_total  \
# 89   Georgia Southern    2.231788           337  2.013245         304
# 59        Wake Forest    2.534483           294  2.275862         264
# 67            Memphis    2.355072           325  2.159420         298
# 110           Rutgers    1.871795           219  1.675214         196
# 31                SMU    2.833333           374  2.696970         356
# ..                ...         ...           ...       ...         ...
# 41         Penn State    2.247788           254  2.530973         286
# 15          Texas A&M    2.741071           307  3.035714         340
# 65     Oklahoma State    1.948052           300  2.162338         333
# 20          Louisiana    2.607692           339  2.876923         374
# 87          Tennessee    1.713043           197  2.017391         232
#
#      num_drives  diff_total
# 89          151          33
# 59          116          30
# 67          138          27
# 110         117          23
# 31          132          18
# ..          ...         ...
# 41          113         -32
# 15          112         -33
# 65          154         -33
# 20          130         -35
# 87          115         -35
#
# [129 rows x 7 columns]

# %% [markdown]
# ## Look at Predictions on a Game Level -- Who Should Have Won on Average?

# %%
## define function to create in-game graphs

def create_graph(drives = drives20, game_id = 401247295, color1 = "black", color2 = "slategray"):
    game_drives = drives.query('game_id == @game_id')

    team_one = game_drives.offense.unique()[0]
    team_two = game_drives.offense.unique()[1]

    team_one_drives = game_drives.query('offense == @team_one')
    team_two_drives = game_drives.query('offense == @team_two')

    x1 = team_one_drives.drive_number
    x2 = team_two_drives.drive_number
    y1 = team_one_drives.predicted_points.cumsum()
    y2 = team_two_drives.predicted_points.cumsum()

    path1 = pd.Series(team_one).repeat(len(x1))
    path2 = pd.Series(team_two).repeat(len(x1))

    #instantiate plot
    fig, ax = plt.subplots()
    ax.plot(x1, y1, color = color1)
    ax.plot(x2, y2, color = color2)

    # Cycle through each point and add an image annotation
    for x0, y0, path in zip(x1, y1, path1):
        ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
        ax.add_artist(ab)
    for x0, y0, path in zip(x2, y2, path2):
        ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
        ax.add_artist(ab)
    
    #paste title text together
    title = ["Predicted", "Points", "per", "Drive: ", team_one, "vs.", team_two]
    
    #add labels to plot
    plt.title(" ".join(title))
    plt.xlabel("Drive Number")
    plt.ylabel("Predicted Points")
    
    #return plot
    return(plt.show())

# %% [markdown]
# ## Penn State @ Indiana (2020)
# ### Actual Score: Penn State   35  -  36   Indiana

# %%
create_graph(drives = drives20, game_id = 401247295, color1 = "midnightblue", color2 = "darkred")

# %% [markdown]
# The above game is somewhat of an anomoly. Indiana actually won this game when they were predicted to lose by 3 or 4 touchdowns. This is because Penn State turned the ball over multiple times in scoring territory and constantly gave Indiana a short field for their offense to work with. The total offensive output was better from Penn State, but they made catastrophic mistakes that cost them the game. Maybe in this case, Penn State fans could clame "Indiana didn't win the game, we lost the game."

# %% [markdown]
# ## BYU @ Coastal Carolina (2020)
# ### Actual Score: BYU   17  -  22   Coastal Carolina

# %%
create_graph(drives = drives20, game_id = 401237514, color1 = "teal", color2 = "navy")

# %% [markdown]
# As a die-hard BYU fan I have a vetted interest in this game. This game was deemed by many as the game of the season in which Coastal Carolina came on top with a 22-17 victory. I remember watching this game and feeling frustrated that the BYU offense did not come away with more points. The Cougars ended with a 27 Predicted Points, 10 more than they actually scored. A big reason for this is because the model has BYU scoring on drive 11 and drive 21. However, in reality both of these drives ended up in zero points. This is because these drives both ended the halves of the game and BYU ran out of time to score before time ran out. In this case, a claim could be made that with slighly better clock management and time on the clock, those drives could have ended in points.

# %% [markdown]
# ## BYU @ Utah (2018)
# ### Actual Score: BYU   27  -  35   Utah
# ***Note: The data from this game was used to train/test the model

# %%
create_graph(drives = drives18, game_id = 401012802, color1 = "navy", color2 = "crimson")

# %% [markdown]
# The previous BYU-Coastal game had a total predicted score 19 points higher than the acutal score. This BYU-Utah game from 2018 has the opposite with a predicted points value 17 points lower than the actual score. This game also has a predicted outcome that was different than reality as the model predicted a BYU win but Utah ended up winning in the end. This brings up a very important aspect of this model: The model predicts ON AVERAGE. One of the great parts about football and sports in general is that there is so much variability. BYU may have won this game given the individual drive statistics on averge, but on this given day the performance by Utah was 'above avergage' and really not out of the ordinary. In other words, BYU fans can not claim that they 'should' have won the game.

# %% [markdown]
# ## BYU vs UTSA (2020)
# ### Actual Score: BYU   27  -  20   UTSA

# %%
create_graph(game_id = 401240997, color1 = "navy")

# %% [markdown]
# ## Clemson @ Notre Dame (2020)
# ### Actual Score: Clemson   40  -  47   Notre Dame

# %%
create_graph(game_id = 401234632, color2 = "darkorange")

# %% [markdown]
# ## Whole Season Offensive and Defensive Predicted Points per Team

# %%
#look at total offensive compared to defensive Predicted Drive Points

#add defensive predicted points per drive to existing data frame
points_per_drive_d = points_per_drive.merge(drives20.groupby('defense').agg(actual_avg_def = ('actual_points', 'mean'), actual_total_def = ('actual_points', 'sum'), pred_avg_def = ('predicted_points', 'mean'), pred_total_def = ('predicted_points', 'sum'), num_drives_def = ('drive_id', 'count')).reset_index().query('num_drives_def > 35'), how = "inner", left_on = 'offense', right_on = 'defense')

#PLOT

#get team names to put into file path later
paths = points_per_drive_d['offense']

x = points_per_drive_d['pred_avg']
y = points_per_drive_d['pred_avg_def']

#instantiate plot
fig, ax = plt.subplots()
ax.scatter(x, y) 

# Cycle through each point and add an image annotation
for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

# Define labels and title
plt.title("Predicted Offensive Points vs Predicted Defensive Points\n(2020 Season)\n")
plt.xlabel('\nPredicted Offensive Points per Drive\n')
plt.ylabel('Predicted Defensive Points per Drive\n')
plt.gca().invert_yaxis()
plt.show()
